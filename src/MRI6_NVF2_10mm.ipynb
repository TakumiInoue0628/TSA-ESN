# %%
import os
import pickle
from lib.methods import LoadCSV, PreProcessing, EchoStateNetwork, Figure
import warnings
warnings.simplefilter('ignore')

fig = Figure({
            'font.family':'Times New Roman',
            'mathtext.fontset':'stix',
            'font.size':30
            })

# %%
os.chdir('../')

# %%
FILE_DIR = './data/VF_FVF_DATASETS/CSV/'
DATA_NAME = 'MRI6_NVF2_10mm_0p4mmV_1'
ADDITIONAL_PATH = ''
SAMPLE_SPAN = [110000, 130000]
FILTER_METHOD = 'bandpass_filtering'
BANDPASS_PARAMS = {
                'passband_edge_freq':[90, 200], 
                'stopband_edge_freq':[20, 450], 
                'passband_edge_max_loss':1, 
                'stopband_edge_min_loss':10
                }
ESN_PARAMS = {
            'units':500, 
            'SR':0.7, 
            'input_shape':10, 
            'output_shape':10, 
            'W_in_scale':0.1, 
            'W_res_density':0.1, 
            'leak_rate':1.0, 
            'alpha':0.01, 
            'seed':0
            }
TRAIN_TEST_DATA_PARAMS = {
                        'n_shift':10,
                        'n_dimension':10,
                        'n_train':5000,
                        'n_predstep':1
                        }
MODEL_DIR = './results/esn_model/'

# %%
FILE_DIR = './data/VF_FVF_DATASETS/CSV/'
DATA_NAME = 'MRI6_NVF2_10mm_0p6mmV_1'
ADDITIONAL_PATH = ''
SAMPLE_SPAN = [100000, 160000]
FILTER_METHOD = 'bandpass_filtering'
BANDPASS_PARAMS = {
                'passband_edge_freq':[90, 200], 
                'stopband_edge_freq':[20, 450], 
                'passband_edge_max_loss':1, 
                'stopband_edge_min_loss':10
                }
ESN_PARAMS = {
            'units':500, 
            'SR':0.5, 
            'input_shape':10, 
            'output_shape':10, 
            'W_in_scale':0.1, 
            'W_res_density':0.1, 
            'leak_rate':1.0, 
            'alpha':0.01, 
            'seed':0
            }
TRAIN_TEST_DATA_PARAMS = {
                        'n_shift':10,
                        'n_dimension':10,
                        'n_train':5000,
                        'n_predstep':1
                        }
MODEL_DIR = './results/esn_model/'

# %%
FILE_DIR = './data/VF_FVF_DATASETS/CSV/'
DATA_NAME = 'MRI6_NVF2_10mm_0p8mmV_1'
ADDITIONAL_PATH = ''
SAMPLE_SPAN = [160000, 180000]
FILTER_METHOD = 'bandpass_filtering'
BANDPASS_PARAMS = {
                'passband_edge_freq':[90, 200], 
                'stopband_edge_freq':[20, 450], 
                'passband_edge_max_loss':1, 
                'stopband_edge_min_loss':10
                }
ESN_PARAMS = {
            'units':500, 
            'SR':0.3, 
            'input_shape':10, 
            'output_shape':10, 
            'W_in_scale':0.1, 
            'W_res_density':0.1, 
            'leak_rate':1.0, 
            'alpha':0.005, 
            'seed':0
            }
TRAIN_TEST_DATA_PARAMS = {
                        'n_shift':10,
                        'n_dimension':10,
                        'n_train':5000,
                        'n_predstep':1
                        }
MODEL_DIR = './results/esn_model/'

# %%
FILE_DIR = './data/VF_FVF_DATASETS/CSV/'
DATA_NAME = 'MRI6_NVF2_10mm_1p0mmV_1'
ADDITIONAL_PATH = ''
SAMPLE_SPAN = [150000, 180000]
FILTER_METHOD = 'bandpass_filtering'
BANDPASS_PARAMS = {
                'passband_edge_freq':[90, 200], 
                'stopband_edge_freq':[20, 450], 
                'passband_edge_max_loss':1, 
                'stopband_edge_min_loss':10
                }
ESN_PARAMS = {
            'units':500, 
            'SR':0.3, 
            'input_shape':10, 
            'output_shape':10, 
            'W_in_scale':0.1, 
            'W_res_density':0.1, 
            'leak_rate':1.0, 
            'alpha':0.001, 
            'seed':0
            }
TRAIN_TEST_DATA_PARAMS = {
                        'n_shift':10,
                        'n_dimension':10,
                        'n_train':5000,
                        'n_predstep':1
                        }
MODEL_DIR = './results/esn_model/'

# %%
FILE_DIR = './data/VF_FVF_DATASETS/CSV/'
DATA_NAME = 'MRI6_NVF2_10mm_1p2mmV_1'
ADDITIONAL_PATH = ''
SAMPLE_SPAN = [150000, 180000]
FILTER_METHOD = 'bandpass_filtering'
BANDPASS_PARAMS = {
                'passband_edge_freq':[90, 200], 
                'stopband_edge_freq':[20, 450], 
                'passband_edge_max_loss':1, 
                'stopband_edge_min_loss':10
                }
ESN_PARAMS = {
            'units':500, 
            'SR':1.0, 
            'input_shape':10, 
            'output_shape':10, 
            'W_in_scale':0.8, 
            'W_res_density':0.1, 
            'leak_rate':1.0, 
            'alpha':0.001, 
            'seed':0
            }
TRAIN_TEST_DATA_PARAMS = {
                        'n_shift':10,
                        'n_dimension':10,
                        'n_train':5000,
                        'n_predstep':1
                        }
MODEL_DIR = './results/esn_model/'

# %%
FILE_DIR = './data/VF_FVF_DATASETS/CSV/'
DATA_NAME = 'MRI6_NVF2_10mm_1p6mmV_1'
ADDITIONAL_PATH = ''
SAMPLE_SPAN = [120000, 150000]
FILTER_METHOD = 'bandpass_filtering'
BANDPASS_PARAMS = {
                'passband_edge_freq':[90, 200], 
                'stopband_edge_freq':[20, 450], 
                'passband_edge_max_loss':1, 
                'stopband_edge_min_loss':10
                }
ESN_PARAMS = {
            'units':500, 
            'SR':1.0, 
            'input_shape':10, 
            'output_shape':10, 
            'W_in_scale':0.3, 
            'W_res_density':0.1, 
            'leak_rate':1.0, 
            'alpha':0.008, 
            'seed':0
            }
TRAIN_TEST_DATA_PARAMS = {
                        'n_shift':10,
                        'n_dimension':10,
                        'n_train':5000,
                        'n_predstep':1
                        }
MODEL_DIR = './results/esn_model/'

# %%
FILE_DIR = './data/VF_FVF_DATASETS/CSV/'
DATA_NAME = 'MRI6_NVF2_10mm_1p8mmV_1'
ADDITIONAL_PATH = ''
SAMPLE_SPAN = [150000, 180000]
FILTER_METHOD = 'bandpass_filtering'
BANDPASS_PARAMS = {
                'passband_edge_freq':[90, 200], 
                'stopband_edge_freq':[20, 450], 
                'passband_edge_max_loss':1, 
                'stopband_edge_min_loss':10
                }
ESN_PARAMS = {
            'units':500, 
            'SR':1.3, 
            'input_shape':10, 
            'output_shape':10, 
            'W_in_scale':0.5, 
            'W_res_density':0.1, 
            'leak_rate':1.0, 
            'alpha':0.002, 
            'seed':0
            }
TRAIN_TEST_DATA_PARAMS = {
                        'n_shift':10,
                        'n_dimension':10,
                        'n_train':5000,
                        'n_predstep':1
                        }
MODEL_DIR = './results/esn_model/'

# %%
FILE_DIR = './data/VF_FVF_DATASETS/CSV/'
DATA_NAME = 'MRI6_NVF2_10mm_2mmV_1'
ADDITIONAL_PATH = ''
SAMPLE_SPAN = [150000, 180000]
FILTER_METHOD = 'bandpass_filtering'
BANDPASS_PARAMS = {
                'passband_edge_freq':[90, 200], 
                'stopband_edge_freq':[20, 450], 
                'passband_edge_max_loss':1, 
                'stopband_edge_min_loss':10
                }
ESN_PARAMS = {
            'units':500, 
            'SR':0.01, 
            'input_shape':10, 
            'output_shape':10, 
            'W_in_scale':0.1, 
            'W_res_density':0.1, 
            'leak_rate':1.0, 
            'alpha':0.001, 
            'seed':0
            }
TRAIN_TEST_DATA_PARAMS = {
                        'n_shift':10,
                        'n_dimension':10,
                        'n_train':5000,
                        'n_predstep':1
                        }
MODEL_DIR = './results/esn_model/'

# %%
[t_data, mic_data] = LoadCSV(
                            file_path=FILE_DIR+DATA_NAME+ADDITIONAL_PATH+'.csv',
                            data_name_list=['t', 'mic'],
                            sample_span=[0, None]
                            )
# Out:
# Loading csv data
# file path | ./data/VF_FVF_DATASETS/CSV/MRI6_NVF2_10mm_1p2mmV_1.csv
# data list | t, mic

# %%
preprocess = PreProcessing(data=mic_data, t_data=t_data)
preprocess.filter(method=FILTER_METHOD, params=BANDPASS_PARAMS)
preprocess.cut(span=SAMPLE_SPAN, new_t=False)
preprocess.embed(n_shift=TRAIN_TEST_DATA_PARAMS['n_shift'], n_dimension=TRAIN_TEST_DATA_PARAMS['n_dimension'])
train_X, train_Y, test_X, test_Y = preprocess.train_test_split(
                                                            n_train=TRAIN_TEST_DATA_PARAMS['n_train'], 
                                                            n_predstep=TRAIN_TEST_DATA_PARAMS['n_predstep']
                                                            )
train_t = preprocess.t_data[TRAIN_TEST_DATA_PARAMS['n_predstep']:TRAIN_TEST_DATA_PARAMS['n_predstep']+train_Y.shape[0]]
test_t = preprocess.t_data[TRAIN_TEST_DATA_PARAMS['n_train']+TRAIN_TEST_DATA_PARAMS['n_predstep']:TRAIN_TEST_DATA_PARAMS['n_train']+TRAIN_TEST_DATA_PARAMS['n_predstep']+test_Y.shape[0]]

# %%
esn = EchoStateNetwork(
                    units=ESN_PARAMS['units'], 
                    SR=ESN_PARAMS['SR'], 
                    input_shape=ESN_PARAMS['input_shape'], 
                    output_shape=ESN_PARAMS['output_shape'], 
                    W_in_scale=ESN_PARAMS['W_in_scale'], 
                    W_res_density=ESN_PARAMS['W_res_density'], 
                    leak_rate=ESN_PARAMS['leak_rate'], 
                    alpha=ESN_PARAMS['alpha'], 
                    seed=ESN_PARAMS['seed']
                    )

esn.fit(in_layer_data=train_X, out_layer_data=train_Y)

pred_test_Y = esn.predict(test_X)
fig.plt_timeseries_of_data_and_model(test_Y[:, 0, 0], pred_test_Y[:, 0], test_t, 4000)

n_freerun = 5000
freerun_test_Y = esn.freerun(in_layer_data0=test_X[0], pred_range=n_freerun, return_reservoir=False)
fig.plt_timeseries_of_data_and_model(test_Y[:, 0, 0], freerun_test_Y[:, 0], test_t, 4000)
fig.plt_attractor_of_data_and_model(test_Y[2000:, 0, 0], freerun_test_Y[2000:, 0], 3000, 20, same_lim=False)

# %%
lyapunov_exponents, dims = esn.computing_lyapunov_exponent(dt=t_data[1]-t_data[0])
fig.plt_lyapunov_exponents(lyapunov_exponents)

# %%
pickle.dump(esn, open(MODEL_DIR+DATA_NAME+'.pkl', "wb"))

# %%
DATA_NAME = 'MRI6_NVF2_10mm_0p4mmV_1'
FILE_DIR = './data/VF_FVF_DATASETS/CSV/'
MODEL_DIR = './results/esn_model/'
FIGURE_DIR = './results/figure/'
SAMPLE_SPAN = [110000, 130000]
FILTER_METHOD = 'bandpass_filtering'
BANDPASS_PARAMS = {
                'passband_edge_freq':[90, 200], 
                'stopband_edge_freq':[20, 450], 
                'passband_edge_max_loss':1, 
                'stopband_edge_min_loss':10
                }
TRAIN_TEST_DATA_PARAMS = {
                        'n_shift':10,
                        'n_dimension':10,
                        'n_train':5000,
                        'n_predstep':1
                        }
[t_data, mic_data] = LoadCSV(file_path=FILE_DIR+DATA_NAME+'.csv', data_name_list=['t', 'mic'], sample_span=[0, None])
preprocess = PreProcessing(data=mic_data, t_data=t_data)
preprocess.filter(method=FILTER_METHOD, params=BANDPASS_PARAMS)
preprocess.cut(span=SAMPLE_SPAN, new_t=False)
preprocess.embed(n_shift=TRAIN_TEST_DATA_PARAMS['n_shift'], n_dimension=TRAIN_TEST_DATA_PARAMS['n_dimension'])
_, _, _, test_Y = preprocess.train_test_split(n_train=TRAIN_TEST_DATA_PARAMS['n_train'], n_predstep=TRAIN_TEST_DATA_PARAMS['n_predstep'])
test_t = preprocess.t_data[TRAIN_TEST_DATA_PARAMS['n_train']+TRAIN_TEST_DATA_PARAMS['n_predstep']:TRAIN_TEST_DATA_PARAMS['n_train']+TRAIN_TEST_DATA_PARAMS['n_predstep']+test_Y.shape[0]]
esn = pickle.load(open(MODEL_DIR+DATA_NAME+'.pkl', 'rb'))
fig.plt_2attractors_powerspectra_lyapunov(test_Y[:, 0, 0], esn.freerun_ans[:, 0], test_t[:], esn.lyapunov_exponents,
                                          n_shift=20, n_initdel=3000, n_plt=2000, freq_lim=(50, 350), lyapunov_lim=(-160, 60), same_lim=False,
                                          save_filename=FIGURE_DIR+DATA_NAME+'.png')
# Out:
# Loading csv data
# file path | ./data/VF_FVF_DATASETS/CSV/MRI6_NVF2_10mm_0p4mmV_1.csv
# data list | t, mic

# %%
DATA_NAME = 'MRI6_NVF2_10mm_0p6mmV_1'
FILE_DIR = './data/VF_FVF_DATASETS/CSV/'
MODEL_DIR = './results/esn_model/'
FIGURE_DIR = './results/figure/'
SAMPLE_SPAN = [100000, 160000]
FILTER_METHOD = 'bandpass_filtering'
BANDPASS_PARAMS = {
                'passband_edge_freq':[90, 200], 
                'stopband_edge_freq':[20, 450], 
                'passband_edge_max_loss':1, 
                'stopband_edge_min_loss':10
                }
TRAIN_TEST_DATA_PARAMS = {
                        'n_shift':10,
                        'n_dimension':10,
                        'n_train':5000,
                        'n_predstep':1
                        }
[t_data, mic_data] = LoadCSV(file_path=FILE_DIR+DATA_NAME+'.csv', data_name_list=['t', 'mic'], sample_span=[0, None])
preprocess = PreProcessing(data=mic_data, t_data=t_data)
preprocess.filter(method=FILTER_METHOD, params=BANDPASS_PARAMS)
preprocess.cut(span=SAMPLE_SPAN, new_t=False)
preprocess.embed(n_shift=TRAIN_TEST_DATA_PARAMS['n_shift'], n_dimension=TRAIN_TEST_DATA_PARAMS['n_dimension'])
_, _, _, test_Y = preprocess.train_test_split(n_train=TRAIN_TEST_DATA_PARAMS['n_train'], n_predstep=TRAIN_TEST_DATA_PARAMS['n_predstep'])
test_t = preprocess.t_data[TRAIN_TEST_DATA_PARAMS['n_train']+TRAIN_TEST_DATA_PARAMS['n_predstep']:TRAIN_TEST_DATA_PARAMS['n_train']+TRAIN_TEST_DATA_PARAMS['n_predstep']+test_Y.shape[0]]
esn = pickle.load(open(MODEL_DIR+DATA_NAME+'.pkl', 'rb'))
fig.plt_2attractors_powerspectra_lyapunov(test_Y[:, 0, 0], esn.freerun_ans[:, 0], test_t[:], esn.lyapunov_exponents,
                                          n_initdel=3000, n_plt=2000, n_shift=25, freq_lim=(50, 300), lyapunov_lim=(-80, 30), same_lim=False,
                                          save_filename=FIGURE_DIR+DATA_NAME+'.png')
# Out:
# Loading csv data
# file path | ./data/VF_FVF_DATASETS/CSV/MRI6_NVF2_10mm_0p6mmV_1.csv
# data list | t, mic

# %%
DATA_NAME = 'MRI6_NVF2_10mm_0p8mmV_1'
FILE_DIR = './data/VF_FVF_DATASETS/CSV/'
MODEL_DIR = './results/esn_model/'
FIGURE_DIR = './results/figure/'
SAMPLE_SPAN = [160000, 180000]
FILTER_METHOD = 'bandpass_filtering'
BANDPASS_PARAMS = {
                'passband_edge_freq':[90, 200], 
                'stopband_edge_freq':[20, 450], 
                'passband_edge_max_loss':1, 
                'stopband_edge_min_loss':10
                }
TRAIN_TEST_DATA_PARAMS = {
                        'n_shift':10,
                        'n_dimension':10,
                        'n_train':5000,
                        'n_predstep':1
                        }
[t_data, mic_data] = LoadCSV(file_path=FILE_DIR+DATA_NAME+'.csv', data_name_list=['t', 'mic'], sample_span=[0, None])
preprocess = PreProcessing(data=mic_data, t_data=t_data)
preprocess.filter(method=FILTER_METHOD, params=BANDPASS_PARAMS)
preprocess.cut(span=SAMPLE_SPAN, new_t=False)
preprocess.embed(n_shift=TRAIN_TEST_DATA_PARAMS['n_shift'], n_dimension=TRAIN_TEST_DATA_PARAMS['n_dimension'])
_, _, _, test_Y = preprocess.train_test_split(n_train=TRAIN_TEST_DATA_PARAMS['n_train'], n_predstep=TRAIN_TEST_DATA_PARAMS['n_predstep'])
test_t = preprocess.t_data[TRAIN_TEST_DATA_PARAMS['n_train']+TRAIN_TEST_DATA_PARAMS['n_predstep']:TRAIN_TEST_DATA_PARAMS['n_train']+TRAIN_TEST_DATA_PARAMS['n_predstep']+test_Y.shape[0]]
esn = pickle.load(open(MODEL_DIR+DATA_NAME+'.pkl', 'rb'))
fig.plt_2attractors_powerspectra_lyapunov(test_Y[:, 0, 0], esn.freerun_ans[:, 0], test_t[:], esn.lyapunov_exponents,
                                          n_initdel=4000, n_plt=1000, n_shift=25, freq_lim=(50, 300), lyapunov_lim=(-140, 40),
                                          save_filename=FIGURE_DIR+DATA_NAME+'.png')
# Out:
# Loading csv data
# file path | ./data/VF_FVF_DATASETS/CSV/MRI6_NVF2_10mm_0p8mmV_1.csv
# data list | t, mic

# %%
DATA_NAME = 'MRI6_NVF2_10mm_1p0mmV_1'
FILE_DIR = './data/VF_FVF_DATASETS/CSV/'
MODEL_DIR = './results/esn_model/'
FIGURE_DIR = './results/figure/'
SAMPLE_SPAN = [150000, 180000]
FILTER_METHOD = 'bandpass_filtering'
BANDPASS_PARAMS = {
                'passband_edge_freq':[90, 200], 
                'stopband_edge_freq':[20, 450], 
                'passband_edge_max_loss':1, 
                'stopband_edge_min_loss':10
                }
TRAIN_TEST_DATA_PARAMS = {
                        'n_shift':10,
                        'n_dimension':10,
                        'n_train':5000,
                        'n_predstep':1
                        }
[t_data, mic_data] = LoadCSV(file_path=FILE_DIR+DATA_NAME+'.csv', data_name_list=['t', 'mic'], sample_span=[0, None])
preprocess = PreProcessing(data=mic_data, t_data=t_data)
preprocess.filter(method=FILTER_METHOD, params=BANDPASS_PARAMS)
preprocess.cut(span=SAMPLE_SPAN, new_t=False)
preprocess.embed(n_shift=TRAIN_TEST_DATA_PARAMS['n_shift'], n_dimension=TRAIN_TEST_DATA_PARAMS['n_dimension'])
_, _, _, test_Y = preprocess.train_test_split(n_train=TRAIN_TEST_DATA_PARAMS['n_train'], n_predstep=TRAIN_TEST_DATA_PARAMS['n_predstep'])
test_t = preprocess.t_data[TRAIN_TEST_DATA_PARAMS['n_train']+TRAIN_TEST_DATA_PARAMS['n_predstep']:TRAIN_TEST_DATA_PARAMS['n_train']+TRAIN_TEST_DATA_PARAMS['n_predstep']+test_Y.shape[0]]
esn = pickle.load(open(MODEL_DIR+DATA_NAME+'.pkl', 'rb'))
fig.plt_2attractors_powerspectra_lyapunov(test_Y[:, 0, 0], esn.freerun_ans[:, 0], test_t[:], esn.lyapunov_exponents,
                                          n_initdel=3000, n_plt=2000, n_shift=25, freq_lim=(50, 300), lyapunov_lim=(-80, 30),
                                          save_filename=FIGURE_DIR+DATA_NAME+'.png')
# Out:
# Loading csv data
# file path | ./data/VF_FVF_DATASETS/CSV/MRI6_NVF2_10mm_1p0mmV_1.csv
# data list | t, mic

# %%
DATA_NAME = 'MRI6_NVF2_10mm_1p2mmV_1'
FILE_DIR = './data/VF_FVF_DATASETS/CSV/'
MODEL_DIR = './results/esn_model/'
FIGURE_DIR = './results/figure/'
SAMPLE_SPAN = [150000, 180000]
FILTER_METHOD = 'bandpass_filtering'
BANDPASS_PARAMS = {
                'passband_edge_freq':[90, 200], 
                'stopband_edge_freq':[20, 450], 
                'passband_edge_max_loss':1, 
                'stopband_edge_min_loss':10
                }
TRAIN_TEST_DATA_PARAMS = {
                        'n_shift':10,
                        'n_dimension':10,
                        'n_train':5000,
                        'n_predstep':1
                        }
[t_data, mic_data] = LoadCSV(file_path=FILE_DIR+DATA_NAME+'.csv', data_name_list=['t', 'mic'], sample_span=[0, None])
preprocess = PreProcessing(data=mic_data, t_data=t_data)
preprocess.filter(method=FILTER_METHOD, params=BANDPASS_PARAMS)
preprocess.cut(span=SAMPLE_SPAN, new_t=False)
preprocess.embed(n_shift=TRAIN_TEST_DATA_PARAMS['n_shift'], n_dimension=TRAIN_TEST_DATA_PARAMS['n_dimension'])
_, _, _, test_Y = preprocess.train_test_split(n_train=TRAIN_TEST_DATA_PARAMS['n_train'], n_predstep=TRAIN_TEST_DATA_PARAMS['n_predstep'])
test_t = preprocess.t_data[TRAIN_TEST_DATA_PARAMS['n_train']+TRAIN_TEST_DATA_PARAMS['n_predstep']:TRAIN_TEST_DATA_PARAMS['n_train']+TRAIN_TEST_DATA_PARAMS['n_predstep']+test_Y.shape[0]]
esn = pickle.load(open(MODEL_DIR+DATA_NAME+'.pkl', 'rb'))
fig.plt_2attractors_powerspectra_lyapunov(test_Y[:, 0, 0], esn.freerun_ans[:, 0], test_t[:], esn.lyapunov_exponents,
                                          n_initdel=2000, n_plt=3000, n_shift=25, freq_lim=(50, 350), lyapunov_lim=(-170, 70), same_lim=False,
                                          save_filename=FIGURE_DIR+DATA_NAME+'.png')
# Out:
# Loading csv data
# file path | ./data/VF_FVF_DATASETS/CSV/MRI6_NVF2_10mm_1p2mmV_1.csv
# data list | t, mic

# %%
DATA_NAME = 'MRI6_NVF2_10mm_1p6mmV_1'
FILE_DIR = './data/VF_FVF_DATASETS/CSV/'
MODEL_DIR = './results/esn_model/'
FIGURE_DIR = './results/figure/'
SAMPLE_SPAN = [120000, 150000]
FILTER_METHOD = 'bandpass_filtering'
BANDPASS_PARAMS = {
                'passband_edge_freq':[90, 200], 
                'stopband_edge_freq':[20, 450], 
                'passband_edge_max_loss':1, 
                'stopband_edge_min_loss':10
                }
TRAIN_TEST_DATA_PARAMS = {
                        'n_shift':10,
                        'n_dimension':10,
                        'n_train':5000,
                        'n_predstep':1
                        }
[t_data, mic_data] = LoadCSV(file_path=FILE_DIR+DATA_NAME+'.csv', data_name_list=['t', 'mic'], sample_span=[0, None])
preprocess = PreProcessing(data=mic_data, t_data=t_data)
preprocess.filter(method=FILTER_METHOD, params=BANDPASS_PARAMS)
preprocess.cut(span=SAMPLE_SPAN, new_t=False)
preprocess.embed(n_shift=TRAIN_TEST_DATA_PARAMS['n_shift'], n_dimension=TRAIN_TEST_DATA_PARAMS['n_dimension'])
_, _, _, test_Y = preprocess.train_test_split(n_train=TRAIN_TEST_DATA_PARAMS['n_train'], n_predstep=TRAIN_TEST_DATA_PARAMS['n_predstep'])
test_t = preprocess.t_data[TRAIN_TEST_DATA_PARAMS['n_train']+TRAIN_TEST_DATA_PARAMS['n_predstep']:TRAIN_TEST_DATA_PARAMS['n_train']+TRAIN_TEST_DATA_PARAMS['n_predstep']+test_Y.shape[0]]
esn = pickle.load(open(MODEL_DIR+DATA_NAME+'.pkl', 'rb'))
fig.plt_2attractors_powerspectra_lyapunov(test_Y[:, 0, 0], esn.freerun_ans[:, 0], test_t[:], esn.lyapunov_exponents,
                                          n_initdel=0, n_plt=3500, n_shift=20, freq_lim=(50, 300), lyapunov_lim=(-160, 60), same_lim=False, transpose_model=True,
                                          save_filename=FIGURE_DIR+DATA_NAME+'.png')
# Out:
# Loading csv data
# file path | ./data/VF_FVF_DATASETS/CSV/MRI6_NVF2_10mm_1p6mmV_1.csv
# data list | t, mic

# %%
DATA_NAME = 'MRI6_NVF2_10mm_1p8mmV_1'
FILE_DIR = './data/VF_FVF_DATASETS/CSV/'
MODEL_DIR = './results/esn_model/'
FIGURE_DIR = './results/figure/'
SAMPLE_SPAN = [150000, 180000]
FILTER_METHOD = 'bandpass_filtering'
BANDPASS_PARAMS = {
                'passband_edge_freq':[90, 200], 
                'stopband_edge_freq':[20, 450], 
                'passband_edge_max_loss':1, 
                'stopband_edge_min_loss':10
                }
TRAIN_TEST_DATA_PARAMS = {
                        'n_shift':10,
                        'n_dimension':10,
                        'n_train':5000,
                        'n_predstep':1
                        }
[t_data, mic_data] = LoadCSV(file_path=FILE_DIR+DATA_NAME+'.csv', data_name_list=['t', 'mic'], sample_span=[0, None])
preprocess = PreProcessing(data=mic_data, t_data=t_data)
preprocess.filter(method=FILTER_METHOD, params=BANDPASS_PARAMS)
preprocess.cut(span=SAMPLE_SPAN, new_t=False)
preprocess.embed(n_shift=TRAIN_TEST_DATA_PARAMS['n_shift'], n_dimension=TRAIN_TEST_DATA_PARAMS['n_dimension'])
_, _, _, test_Y = preprocess.train_test_split(n_train=TRAIN_TEST_DATA_PARAMS['n_train'], n_predstep=TRAIN_TEST_DATA_PARAMS['n_predstep'])
test_t = preprocess.t_data[TRAIN_TEST_DATA_PARAMS['n_train']+TRAIN_TEST_DATA_PARAMS['n_predstep']:TRAIN_TEST_DATA_PARAMS['n_train']+TRAIN_TEST_DATA_PARAMS['n_predstep']+test_Y.shape[0]]
esn = pickle.load(open(MODEL_DIR+DATA_NAME+'.pkl', 'rb'))
fig.plt_2attractors_powerspectra_lyapunov(test_Y[:, 0, 0], esn.freerun_ans[:, 0], test_t[:], esn.lyapunov_exponents,
                                          n_initdel=2000, n_plt=3000, n_shift=25, freq_lim=(50, 300), lyapunov_lim=(-170, 70), same_lim=False, transpose_model=False,
                                          save_filename=FIGURE_DIR+DATA_NAME+'.png')
# Out:
# Loading csv data
# file path | ./data/VF_FVF_DATASETS/CSV/MRI6_NVF2_10mm_1p8mmV_1.csv
# data list | t, mic

# %%
DATA_NAME = 'MRI6_NVF2_10mm_2mmV_1'
FILE_DIR = './data/VF_FVF_DATASETS/CSV/'
MODEL_DIR = './results/esn_model/'
FIGURE_DIR = './results/figure/'
SAMPLE_SPAN = [150000, 180000]
FILTER_METHOD = 'bandpass_filtering'
BANDPASS_PARAMS = {
                'passband_edge_freq':[90, 200], 
                'stopband_edge_freq':[20, 450], 
                'passband_edge_max_loss':1, 
                'stopband_edge_min_loss':10
                }
TRAIN_TEST_DATA_PARAMS = {
                        'n_shift':10,
                        'n_dimension':10,
                        'n_train':5000,
                        'n_predstep':1
                        }
[t_data, mic_data] = LoadCSV(file_path=FILE_DIR+DATA_NAME+'.csv', data_name_list=['t', 'mic'], sample_span=[0, None])
preprocess = PreProcessing(data=mic_data, t_data=t_data)
preprocess.filter(method=FILTER_METHOD, params=BANDPASS_PARAMS)
preprocess.cut(span=SAMPLE_SPAN, new_t=False)
preprocess.embed(n_shift=TRAIN_TEST_DATA_PARAMS['n_shift'], n_dimension=TRAIN_TEST_DATA_PARAMS['n_dimension'])
_, _, _, test_Y = preprocess.train_test_split(n_train=TRAIN_TEST_DATA_PARAMS['n_train'], n_predstep=TRAIN_TEST_DATA_PARAMS['n_predstep'])
test_t = preprocess.t_data[TRAIN_TEST_DATA_PARAMS['n_train']+TRAIN_TEST_DATA_PARAMS['n_predstep']:TRAIN_TEST_DATA_PARAMS['n_train']+TRAIN_TEST_DATA_PARAMS['n_predstep']+test_Y.shape[0]]
esn = pickle.load(open(MODEL_DIR+DATA_NAME+'.pkl', 'rb'))
fig.plt_2attractors_powerspectra_lyapunov(test_Y[:, 0, 0], esn.freerun_ans[:, 0], test_t[:], esn.lyapunov_exponents,
                                          n_initdel=3000, n_plt=2000, n_shift=20, freq_lim=(50, 300), lyapunov_lim=(-150, 50), same_lim=True,
                                          save_filename=FIGURE_DIR+DATA_NAME+'.png')
# Out:
# Loading csv data
# file path | ./data/VF_FVF_DATASETS/CSV/MRI6_NVF2_10mm_2mmV_1.csv
# data list | t, mic
