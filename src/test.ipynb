# %%
import matplotlib.pylab as plt

# %%
rcParams_dict = {'font.family':'Times New Roman', "font.size": 30}

# %%
for key in rcParams_dict.keys():
            plt.rcParams[str(key)] = rcParams_dict[str(key)]

# %%
plt.plot([0, 1, 2, 3])
plt.xlabel('hello')
# Out:
# Text(0.5, 0, 'hello')
